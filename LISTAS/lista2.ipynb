# %%
import numpy as np

# 1 á 10
array1 = [list(range(1, 21))] # 0 a 20

array2 = [list(range(0, 51, 2))] # pares de 0 a 50

vetor3 = np.zeros(100) 

matriz4 = np.full((4,4), 1) # 4x4 de 1

vetor5 = np.linspace(0, 1, 50) # 49 números entre 0 e 1

vetor6 = np.random.uniform(1, 101, 100) # 100 aleatórios uniformes entre 1 e 100

vetor7 = np.random.normal(0, 5, 100) # distribuição normal/gauss

matriz8 = np.random.rand(5,5)

media9 = np.random.rand(100)
media9 = np.mean(media9)

std10 = np.random.rand(100)
std10 = np.mean(std10)

# %%
teste1 = np.random.randint(1, 101, size=10)
teste2 = np.random.randint(1, 101, size=10)

# 11 á 16

soma11 = teste1 + teste2

mult12 = teste2 * 10

sin13 = np.sin(teste1)

log14 = np.log(teste2) # isso na verdade é um ln, mas é o padrão

matriz15 = np.random.randint(1, 101, size=(3,3))
transposta15 = np.transpose(matriz15)

matriz16 = np.random.randint(1, 11, size=(2,2))
det16 = np.linalg.det(matriz16)

# %%
matriz_teste1 = np.random.randint(1, 11, size=(3,3))
matriz_teste2 = np.random.randint(1, 11, size=(3,3))
vetor_teste = np.random.randint(1, 101, 10)
vetor_teste2 = np.random.uniform(-1, 1, 10)
retornos_financeiros = np.random.randint(0, 10000, size=100)

# 17 á 26

produto17 = matriz_teste1 @ matriz_teste2

media18 = np.random.randint(1, 101, size=(100, 100))
matriz18 = np.mean(media18)

max19 = np.max(matriz_teste1)

min20 = np.min(matriz_teste2)

sort21 = np.sort(vetor_teste)

inverso22 = vetor_teste[::-1]

q_23 = vetor_teste2[vetor_teste2 > 0.5]

q_24 = np.where( vetor_teste2 < 0, 0, vetor_teste2)

q_25 = (vetor_teste - np.min(vetor_teste)) / (np.max(vetor_teste) - np.min(vetor_teste))

q_26 = np.mean(retornos_financeiros)
# Out:
# 2.0478989575251916
# [50 28 14 11 99 35 98 81 51 33]

# %%
# Questão 27 á 334

import numpy as np

passos = np.random.normal(0, 1, 1000)
matriz1 = np.random.randint(1, 101, size=(3,3))
matriz2 = np.random.randint(1, 101, size=(3,3))

q_27 = 150 + np.cumsum(passos)

q_28 = np.identity(5)

q_29 = matriz1 * matriz2

q_30 = np.linalg.inv(matriz1)

q_31 = np.diag(np.diag(matriz1))

q_32 = np.diag(matriz2)

q_33 = np.sum(matriz1, axis=1)

q_34 = np.sum(matriz2, axis=0)

# %%
#Questão 35 e 36

import time
import numpy as np

matriz1 = np.random.rand(1000,1000)
matriz2 = np.random.rand(1000,1000)

inicio1 = time.time()
resultado = matriz1 @ matriz2 
fim1 = time.time()

print(f"Tempo de execução do Numpy: {fim1 - inicio1:.4f} segundos")

inicio2 = time.time()
for i in range(1000):
    for j in range(1000):
        for k in range(1000):
            pass # uma função de det tem 3 loops aninhados, e ainda não faz nenhum cálculo
fim2 = time.time()

print(f"Tempo de execução do Loop: {fim2 - inicio2:.4f} segundos")
# Out:
# Tempo de execução do Numpy: 0.2361 segundos
# Tempo de execução do Loop: 54.6469 segundos

# %%
#Questão 37

retornos = 1 + np.random.normal(0.001, 0.05, 10000)

resultados = retornos.cumprod()

print(resultados)
# Out:
# [1.01440304 1.09315047 1.10513191 ... 0.03035903 0.03148934 0.02914633]
