# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

iris = load_iris()
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target,
random_state=100)

knn = KNeighborsClassifier(n_neighbors=3, weights='distance', algorithm='auto',
    leaf_size=30, metric='minkowski', p=2, n_jobs=1)
#INSTÂNCIA DO KNN

knn.fit(x_train, y_train)
#TREINAMENTO DO MODELO

test = knn.predict(x_test)
#PREVISÃO

accuracy = np.mean(test == y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9736842105263158

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import svm

iris = load_iris()
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=100) 
#DIVISÂO DE CASOS DE TESTE E TREINO

C = 1.0
#PARÂMETRO DO SVM

svc = svm.SVC(kernel='linear', C=C)
#INSTÂNCIA DO SVM

svc.fit(x_train, y_train)
#TREINAMENTO 

test = svc.predict(x_test)
#TESTE

accuracy = np.mean(test == y_test)
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Accuracy: 100.00%

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(knn, iris.data, iris.target, cv=10)
# VALIDAÇÃO CRUZADA COM 10 CV / RODADAS

print(scores)
print(f"CV Média: {scores.mean():.2%} ± {scores.std():.2%}")

scores2 = cross_val_score(svc, iris.data, iris.target, cv=15)
print(scores2)
print(f"CV Média: {scores2.mean():.2%} ± {scores2.std():.2%}")
# Out:
# [1.         0.93333333 1.         0.93333333 0.86666667 1.
#  0.93333333 1.         1.         1.        ]
# CV Média: 96.67% ± 4.47%
# [1.  1.  0.9 1.  1.  1.  0.9 1.  1.  0.9 1.  1.  1.  1.  1. ]
# CV Média: 98.00% ± 4.00%

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
    )

print("=" * 45)
print("               KNN — Métricas")
print("=" * 45)
print(f"  Acurácia  : {accuracy_score(y_test, test):.2%}")
print(f"  Precisão  : {precision_score(y_test, test, average='weighted'):.2%}")
print(f"  Recall    : {recall_score(y_test, test, average='weighted'):.2%}")
print(f"  F1-Score  : {f1_score(y_test, test, average='weighted'):.2%}")
print("=" * 45)
print(classification_report(y_test, test, target_names=iris.target_names))
# Out:
# ...
#                KNN — Métricas
# ...
#   Acurácia  : 100.00%
#   Precisão  : 100.00%
#   Recall    : 100.00%
#   F1-Score  : 100.00%
# ...
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       1.00      1.00      1.00        10
#    virginica       1.00      1.00      1.00        14
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
