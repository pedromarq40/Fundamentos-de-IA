# %%
from sklearn.preprocessing import (
    StandardScaler,
    RobustScaler,
    MinMaxScaler
)

"""O StandardScaler no scikit-learn garante que, para cada recurso, a media  ́e zero, e a
variância é um, trazendo todos os recursos para a mesma magnitude."""

"""O RobustScaler combate os outliers, diferente do StandardScaler que usa média e variância.
Este usa médiana e Quartis """

"""O MinMaxScaler, por outro lado, desloca os dados de modo que todos os recursos
sejam exatamente entre 0 e 1. Para o conjunto de dados bidimensional, isso significa
que todos os dados est ̃ao dentro do retângulo criado pelo eixo x entre 0 e 1 e o eixo y
entre 0 e 1."""
